# %% [markdown]
# ### Quality control script
#
# #### - Remove data for dead or abnormal larvae
# #### - Remove incomplete data
# #### - Convert excel files to more efficient .pkl files for future processing.
#
# by: Dr. Adrian Green, *Fall 2020*
#
# ##### Early data (Nov_2019 - March_2020) used the original 18 morphology endpoints. Additional data (Dec_2020) used super-endpoints and was kept aside as validation data.

# %%
# import libraries

import numpy as np
import pandas as pd
import openpyxl
import os
import xlrd 
import sys

from Green_scripts_v1 import save_obj

basedirname = '/home2/ajgreen4/ZF_Projects/HTS_Behavior_Project'

# %%
# Load identification data

# Read in well to arena key
waKey = pd.read_csv(basedirname + "/Raw_Data_Files/well-arena.csv")
[waNumRows, waNumCols] = waKey.shape

# Read in plate to chemical to well key
pcwKey = pd.read_csv(basedirname + "/Raw_Data_Files/plateTable.csv")
[pcwNumRows, pcwNumCols] = pcwKey.shape

# %% [markdown]
# ### Training data (super-endpoints)

# %%
# Define location to look for plateID
timecheck = 0 # set to 1 to output a file with filename, Trial duration, and Recording duration

# output location
dataPath = basedirname + "/QC_Data_Files/OSU_Train_super_endpoints/"

#Validation Files
rawDataPath = basedirname + "/Raw_Data_Files/OSU_Train_super_endpoints/OSU_2020Dec_raw/"

newlist = os.listdir(rawDataPath)
mylist = []
for names in newlist:
    if names.endswith(".xlsx"):
        mylist.append(names)
print("Number of raw data files: ",len(mylist))

# Read in superendpoints morphology data - Validation
morphology_df = pd.read_csv(basedirname + "/Raw_Data_Files/morphology_super.csv")
morphology_df = morphology_df.fillna(0)
# Out:
# Number of raw data files:  8

# %% [markdown]
# #### Code to reads in one ethovision raw export file at a time, delete sheets that don't meet QC requirments and write cleaned excel files to disk.
# ##### Experinental design : 6 minutes acclimation then 18 minutes of light/dark cycling (3 x 2 x 3 min)
# Initial QC need to include the second light cycle therefore 720s to 1080s

# %%
# %%time
try: 
    os.chdir(dataPath) 
# Caching the exception     
except: 
    os.makedirs(dataPath)   

i=j=0
for file in mylist:
    filePath = rawDataPath + file

    # for an earlier version of Excel, you may need to use the file extension of 'xls'
#     noldusDataFile = pd.read_excel(filePath, sheet_name=None, header=None, usecols='A:D,H,I')
    noldusDataFile = pd.read_excel(filePath, sheet_name=None, header=None, usecols=None)

    etho_data_df = []
    try:
        for key, sheet in noldusDataFile.items():
            locData = pd.DataFrame(sheet)
            headerLines = int(locData.loc[0, 1])
            [numRows, numCols] = locData.shape
            # make sure that light cycle data needed are present
            if numRows > 35 and int(locData.loc[headerLines+1,0]) <= 720 and int(locData.loc[numRows-1,0]) >= 1080:
                plateID = ""
                chemID = ""
                well = ""

                try:
                    plateID = int(os.path.splitext(file)[0][0:5])
                except:  
                    try:
                        end = len(os.path.splitext(file)[0])
                        plateID = int(os.path.splitext(file)[0][end-5:end])
                    except:
                        aviName = locData.loc[(locData[0] == 'Video file')].iloc[0,1]
                        end = len(aviName)-4
                        plateID = int(aviName[end-5:end])
                arenaName = int(locData.loc[(locData[0] == 'Arena name')].iloc[0,1])
                well = waKey.loc[(waKey['arena']==arenaName)].iloc[0,0]
                try:
                    chemID = pcwKey.loc[(pcwKey['PlateID']==plateID) & (pcwKey['Well']==well)].iloc[0,1]
                    conc = pcwKey.loc[(pcwKey['PlateID']==plateID) & (pcwKey['Well']==well)].iloc[0,3]

    #                 print("Plate:", plateID, " Chem:", chemID, " Well:", well)
                    # get morphology data for lavae
                    subset_df = morphology_df[(morphology_df.iloc[:,3]==int(plateID)) & 
                                              (morphology_df.iloc[:,4]==well) &
                                              (morphology_df.iloc[:,0]==int(chemID))].iloc[:,6:28].T
                    # if no abnormalities then keep record
                    if int(subset_df.max()):
                        etho_data_df.append(key)
                except:
                    # remove sheets with no chemical info
                    etho_data_df.append(key)
            else:
                # remove sheets with less than 18 minutes of light cycle data
                etho_data_df.append(key)
        for key in etho_data_df:
            del noldusDataFile[key]

        if len(noldusDataFile): # save as pickkle to maintain 3d data structure
            save_obj(noldusDataFile, dataPath, os.path.splitext(file)[0])

        print(len(etho_data_df),' wells removed from ', file)
    except Exception as e:
        print('Error in : ', file, " Plate:", plateID, " Chem:", chemID, " Well:", well)
        print(e)
# Out:
# File saved:  /home2/ajgreen4/ZF_Projects/HTS_Behavior_Project/QC_Data_Files/OSU_Train_super_endpoints/ Raw data-21549 .pkl
# 21  wells removed from  Raw data-21549.xlsx
# File saved:  /home2/ajgreen4/ZF_Projects/HTS_Behavior_Project/QC_Data_Files/OSU_Train_super_endpoints/ Raw data-21548 .pkl
# 19  wells removed from  Raw data-21548.xlsx
# File saved:  /home2/ajgreen4/ZF_Projects/HTS_Behavior_Project/QC_Data_Files/OSU_Train_super_endpoints/ Raw data-21547 .pkl
# 15  wells removed from  Raw data-21547.xlsx
# File saved:  /home2/ajgreen4/ZF_Projects/HTS_Behavior_Project/QC_Data_Files/OSU_Train_super_endpoints/ Raw data-21546 .pkl
# 22  wells removed from  Raw data-21546.xlsx
# File saved:  /home2/ajgreen4/ZF_Projects/HTS_Behavior_Project/QC_Data_Files/OSU_Train_super_endpoints/ Raw data-21543 .pkl
# 26  wells removed from  Raw data-21543.xlsx
# File saved:  /home2/ajgreen4/ZF_Projects/HTS_Behavior_Project/QC_Data_Files/OSU_Train_super_endpoints/ Raw data-21542 .pkl
# 28  wells removed from  Raw data-21542.xlsx
# File saved:  /home2/ajgreen4/ZF_Projects/HTS_Behavior_Project/QC_Data_Files/OSU_Train_super_endpoints/ Raw data-21534 .pkl
# 16  wells removed from  Raw data-21534.xlsx
# File saved:  /home2/ajgreen4/ZF_Projects/HTS_Behavior_Project/QC_Data_Files/OSU_Train_super_endpoints/ Raw data-21532 .pkl
# 19  wells removed from  Raw data-21532.xlsx
# CPU times: user 1h 27min 54s, sys: 7.61 s, total: 1h 28min 1s
# Wall time: 1h 28min 1s

# %% [markdown]
# ### Training data (18 endpoints)

# %%
# Define location to look for plateID
timecheck = 0 # set to 1 to output a file with filename, Trial duration, and Recording duration

# output location
dataPath = basedirname + "/QC_Data_Files/OSU_Train_original_endpoints/"
#Noldus raw data file location
# Training Files
rawDataPath = basedirname + "/Raw_Data_Files/OSU_Train_original_endpoints/"

sublist = os.listdir(rawDataPath)
mylist = []
for subdir in sublist:
    newlist = os.listdir(rawDataPath+subdir+'/')
    for names in newlist:
        if names.endswith(".xlsx"):
            mylist.append(subdir + '/' + names)
print("Number of raw data files: ",len(mylist))

# Read in morphology data - Training
morphology_df = pd.read_csv(basedirname + "/Raw_Data_Files/morphology.csv")
morphology_df = morphology_df.fillna(0)
# Out:
# Number of raw data files:  41

# %% [markdown]
# #### Code to reads in one ethovision raw export file at a time, delete sheets that don't meet QC requirments and write cleaned excel files to disk.
# ##### Experinental design : 6 minutes acclimation then 18 minutes of light/dark cycling (3 x 2 x 3 min)
# Initial QC need to include the second light cycle therefore 720s to 1080s

# %%
# %%time
try: 
    os.chdir(dataPath) 
# Caching the exception     
except: 
    os.makedirs(dataPath)   

i=j=0
for file in mylist:
    filePath = rawDataPath + file

    # for an earlier version of Excel, you may need to use the file extension of 'xls'
#     noldusDataFile = pd.read_excel(filePath, sheet_name=None, header=None, usecols='A:D,H,I')
    noldusDataFile = pd.read_excel(filePath, sheet_name=None, header=None, usecols=None)

    etho_data_df = []
    try:
        for key, sheet in noldusDataFile.items():
            locData = pd.DataFrame(sheet)
            headerLines = int(locData.loc[0, 1])
            [numRows, numCols] = locData.shape
            # make sure that light cycle data needed are present
            if numRows > 35 and int(locData.loc[headerLines+1,0]) <= 720 and int(locData.loc[numRows-1,0]) >= 1080:
                plateID = ""
                chemID = ""
                well = ""

                try:
                    plateID = int(os.path.split(file)[1][0:5])
                except:  
                    try:
                        end = len(os.path.split(file)[1])
                        plateID = int(os.path.split(file)[1][end-5:end])
                    except:
                        aviName = locData.loc[(locData[0] == 'Video file')].iloc[0,1]
                        end = len(aviName)-4
                        plateID = int(aviName[end-5:end])
                arenaName = int(locData.loc[(locData[0] == 'Arena name')].iloc[0,1])
                well = waKey.loc[(waKey['arena']==arenaName)].iloc[0,0]
                try:
                    chemID = pcwKey.loc[(pcwKey['PlateID']==plateID) & (pcwKey['Well']==well)].iloc[0,1]
                    conc = pcwKey.loc[(pcwKey['PlateID']==plateID) & (pcwKey['Well']==well)].iloc[0,3]

    #                 print("Plate:", plateID, " Chem:", chemID, " Well:", well)
                    # get morphology data for lavae
                    subset_df = morphology_df[(morphology_df.iloc[:,3]==int(plateID)) & 
                                              (morphology_df.iloc[:,4]==well) &
                                              (morphology_df.iloc[:,0]==int(chemID))].iloc[:,6:28].T
                    # if no abnormalities then keep record
                    if int(subset_df.max()):
                        etho_data_df.append(key)
                except:
                    # remove sheets with no chemical info
                    etho_data_df.append(key)
            else:
                # remove sheets with less than 18 minutes of light cycle data
                etho_data_df.append(key)
        for key in etho_data_df:
            del noldusDataFile[key]

        if len(noldusDataFile): # save as pickkle to maintain 3d data structure
            save_obj(noldusDataFile, dataPath, os.path.splitext(os.path.basename(file))[0])
            
        print(len(etho_data_df),' wells removed from ', file)
    except Exception as e:
        print('Error in : ', file, " Plate:", plateID, " Chem:", chemID, " Well:", well)
        print(e)
# Out:
# File saved:  /home2/ajgreen4/ZF_Projects/HTS_Behavior_Project/QC_Data_Files/OSU_Train_original_endpoints/ 19861_Raw data .pkl
# 25  wells removed from  OSU_2020Feb_raw/19861_Raw data.xlsx
# File saved:  /home2/ajgreen4/ZF_Projects/HTS_Behavior_Project/QC_Data_Files/OSU_Train_original_endpoints/ 19840-Raw data .pkl
# 9  wells removed from  OSU_2020Feb_raw/19840-Raw data.xlsx
# File saved:  /home2/ajgreen4/ZF_Projects/HTS_Behavior_Project/QC_Data_Files/OSU_Train_original_endpoints/ 19839-Raw data .pkl
# 44  wells removed from  OSU_2020Feb_raw/19839-Raw data.xlsx
# File saved:  /home2/ajgreen4/ZF_Projects/HTS_Behavior_Project/QC_Data_Files/OSU_Train_original_endpoints/ 19833_Raw data .pkl
# 9  wells removed from  OSU_2020Feb_raw/19833_Raw data.xlsx
# File saved:  /home2/ajgreen4/ZF_Projects/HTS_Behavior_Project/QC_Data_Files/OSU_Train_original_endpoints/ 19832_Raw data .pkl
# 24  wells removed from  OSU_2020Feb_raw/19832_Raw data.xlsx
# File saved:  /home2/ajgreen4/ZF_Projects/HTS_Behavior_Project/QC_Data_Files/OSU_Train_original_endpoints/ 19831-Raw data .pkl
# 24  wells removed from  OSU_2020Feb_raw/19831-Raw data.xlsx
# File saved:  /home2/ajgreen4/ZF_Projects/HTS_Behavior_Project/QC_Data_Files/OSU_Train_original_endpoints/ 19828-Raw data .pkl
# 19  wells removed from  OSU_2020Feb_raw/19828-Raw data.xlsx
# File saved:  /home2/ajgreen4/ZF_Projects/HTS_Behavior_Project/QC_Data_Files/OSU_Train_original_endpoints/ 19813_Raw data .pkl
# 14  wells removed from  OSU_2020Feb_raw/19813_Raw data.xlsx
# File saved:  /home2/ajgreen4/ZF_Projects/HTS_Behavior_Project/QC_Data_Files/OSU_Train_original_endpoints/ 19807_Raw data .pkl
# 14  wells removed from  OSU_2020Feb_raw/19807_Raw data.xlsx
# File saved:  /home2/ajgreen4/ZF_Projects/HTS_Behavior_Project/QC_Data_Files/OSU_Train_original_endpoints/ 19323_Raw data .pkl
# 17  wells removed from  OSU_2020Feb_raw/19323_Raw data.xlsx
# File saved:  /home2/ajgreen4/ZF_Projects/HTS_Behavior_Project/QC_Data_Files/OSU_Train_original_endpoints/ 19315_Raw data .pkl
# 15  wells removed from  OSU_2020Feb_raw/19315_Raw data.xlsx
# File saved:  /home2/ajgreen4/ZF_Projects/HTS_Behavior_Project/QC_Data_Files/OSU_Train_original_endpoints/ 19312_Raw data .pkl
# 18  wells removed from  OSU_2020Feb_raw/19312_Raw data.xlsx
# File saved:  /home2/ajgreen4/ZF_Projects/HTS_Behavior_Project/QC_Data_Files/OSU_Train_original_endpoints/ 19309_Raw data .pkl
# 19  wells removed from  OSU_2020Feb_raw/19309_Raw data.xlsx
# File saved:  /home2/ajgreen4/ZF_Projects/HTS_Behavior_Project/QC_Data_Files/OSU_Train_original_endpoints/ 19281_Raw data .pkl
# 64  wells removed from  OSU_2020Feb_raw/19281_Raw data.xlsx
# File saved:  /home2/ajgreen4/ZF_Projects/HTS_Behavior_Project/QC_Data_Files/OSU_Train_original_endpoints/ 19275_Raw data .pkl
# 23  wells removed from  OSU_2020Feb_raw/19275_Raw data.xlsx
# File saved:  /home2/ajgreen4/ZF_Projects/HTS_Behavior_Project/QC_Data_Files/OSU_Train_original_endpoints/ 19267_Raw data .pkl
# 43  wells removed from  OSU_2020Feb_raw/19267_Raw data.xlsx
# File saved:  /home2/ajgreen4/ZF_Projects/HTS_Behavior_Project/QC_Data_Files/OSU_Train_original_endpoints/ 19239_Raw data .pkl
# 23  wells removed from  OSU_2020Feb_raw/19239_Raw data.xlsx
# File saved:  /home2/ajgreen4/ZF_Projects/HTS_Behavior_Project/QC_Data_Files/OSU_Train_original_endpoints/ 19237_Raw data .pkl
# 29  wells removed from  OSU_2020Feb_raw/19237_Raw data.xlsx
# File saved:  /home2/ajgreen4/ZF_Projects/HTS_Behavior_Project/QC_Data_Files/OSU_Train_original_endpoints/ 19231-Raw data .pkl
# 78  wells removed from  OSU_2020Feb_raw/19231-Raw data.xlsx
# File saved:  /home2/ajgreen4/ZF_Projects/HTS_Behavior_Project/QC_Data_Files/OSU_Train_original_endpoints/ 19221-Raw data .pkl
# 61  wells removed from  OSU_2020Feb_raw/19221-Raw data.xlsx
# File saved:  /home2/ajgreen4/ZF_Projects/HTS_Behavior_Project/QC_Data_Files/OSU_Train_original_endpoints/ 19217-Raw data .pkl
# 60  wells removed from  OSU_2020Feb_raw/19217-Raw data.xlsx
# File saved:  /home2/ajgreen4/ZF_Projects/HTS_Behavior_Project/QC_Data_Files/OSU_Train_original_endpoints/ 19216-Raw data .pkl
# 37  wells removed from  OSU_2020Feb_raw/19216-Raw data.xlsx
# 96  wells removed from  OSU_2020Feb_raw/19215-Raw data.xlsx
# File saved:  /home2/ajgreen4/ZF_Projects/HTS_Behavior_Project/QC_Data_Files/OSU_Train_original_endpoints/ 19985_Raw data-2-13-20 analysis-Trial     3 .pkl
# 18  wells removed from  OSU_2020March_raw/19985_Raw data-2-13-20 analysis-Trial     3.xlsx
# File saved:  /home2/ajgreen4/ZF_Projects/HTS_Behavior_Project/QC_Data_Files/OSU_Train_original_endpoints/ 19765-Raw data-02-05-20 analysis-Trial     1 .pkl
# 5  wells removed from  OSU_2020March_raw/19765-Raw data-02-05-20 analysis-Trial     1.xlsx
# File saved:  /home2/ajgreen4/ZF_Projects/HTS_Behavior_Project/QC_Data_Files/OSU_Train_original_endpoints/ 19771_Raw data-2-6-20 analysis-Trial     3 .pkl
# 7  wells removed from  OSU_2020March_raw/19771_Raw data-2-6-20 analysis-Trial     3.xlsx
# File saved:  /home2/ajgreen4/ZF_Projects/HTS_Behavior_Project/QC_Data_Files/OSU_Train_original_endpoints/ 19778_Raw data-2-6-20 analysis-Trial     2 .pkl
# 21  wells removed from  OSU_2020March_raw/19778_Raw data-2-6-20 analysis-Trial     2.xlsx
# 96  wells removed from  OSU_2020March_raw/19780_Raw data-2-6-20 analysis-Trial     1.xlsx
# File saved:  /home2/ajgreen4/ZF_Projects/HTS_Behavior_Project/QC_Data_Files/OSU_Train_original_endpoints/ 19889_Raw data-2-13-20 analysis-Trial     1 .pkl
# 40  wells removed from  OSU_2020March_raw/19889_Raw data-2-13-20 analysis-Trial     1.xlsx
# 96  wells removed from  OSU_2020March_raw/19895_Raw data-2-13-20 analysis-Trial     2.xlsx
# File saved:  /home2/ajgreen4/ZF_Projects/HTS_Behavior_Project/QC_Data_Files/OSU_Train_original_endpoints/ 19944_Raw data-02-05-20 analysis-Trial     3 .pkl
# 57  wells removed from  OSU_2020March_raw/19944_Raw data-02-05-20 analysis-Trial     3.xlsx
# File saved:  /home2/ajgreen4/ZF_Projects/HTS_Behavior_Project/QC_Data_Files/OSU_Train_original_endpoints/ 19986_Raw data-2-13-20 analysis-Trial     4 .pkl
# 20  wells removed from  OSU_2020March_raw/19986_Raw data-2-13-20 analysis-Trial     4.xlsx
# File saved:  /home2/ajgreen4/ZF_Projects/HTS_Behavior_Project/QC_Data_Files/OSU_Train_original_endpoints/ 19731_Raw data-96 well plate LPR template-Trial     1 .pkl
# 14  wells removed from  OSU_2020March_raw/19731_Raw data-96 well plate LPR template-Trial     1.xlsx
# File saved:  /home2/ajgreen4/ZF_Projects/HTS_Behavior_Project/QC_Data_Files/OSU_Train_original_endpoints/ 19746_Raw data-02-7-20_analysis-Trial     1 .pkl
# 21  wells removed from  OSU_2020March_raw/19746_Raw data-02-7-20_analysis-Trial     1.xlsx
# File saved:  /home2/ajgreen4/ZF_Projects/HTS_Behavior_Project/QC_Data_Files/OSU_Train_original_endpoints/ 19764-Raw data-02-05-20 analysis-Trial     2 .pkl
# 13  wells removed from  OSU_2020March_raw/19764-Raw data-02-05-20 analysis-Trial     2.xlsx
# File saved:  /home2/ajgreen4/ZF_Projects/HTS_Behavior_Project/QC_Data_Files/OSU_Train_original_endpoints/ Raw data-18938,18940,18939-Trial     3 .pkl
# 3  wells removed from  OSU_6NOV19_raw/Raw data-18938,18940,18939-Trial     3.xlsx
# File saved:  /home2/ajgreen4/ZF_Projects/HTS_Behavior_Project/QC_Data_Files/OSU_Train_original_endpoints/ Raw data-19054,19052,19051-Trial     1 .pkl
# 35  wells removed from  OSU_6NOV19_raw/Raw data-19054,19052,19051-Trial     1.xlsx
# File saved:  /home2/ajgreen4/ZF_Projects/HTS_Behavior_Project/QC_Data_Files/OSU_Train_original_endpoints/ Raw data-19054,19052,19051-Trial     2 .pkl
# 20  wells removed from  OSU_6NOV19_raw/Raw data-19054,19052,19051-Trial     2.xlsx
# File saved:  /home2/ajgreen4/ZF_Projects/HTS_Behavior_Project/QC_Data_Files/OSU_Train_original_endpoints/ Raw data-19054,19052,19051-Trial     3 .pkl
# 37  wells removed from  OSU_6NOV19_raw/Raw data-19054,19052,19051-Trial     3.xlsx
# File saved:  /home2/ajgreen4/ZF_Projects/HTS_Behavior_Project/QC_Data_Files/OSU_Train_original_endpoints/ Raw data-18938,18940,18939-Trial     1 .pkl
# 3  wells removed from  OSU_6NOV19_raw/Raw data-18938,18940,18939-Trial     1.xlsx
# File saved:  /home2/ajgreen4/ZF_Projects/HTS_Behavior_Project/QC_Data_Files/OSU_Train_original_endpoints/ Raw data-18938,18940,18939-Trial     2 .pkl
# 6  wells removed from  OSU_6NOV19_raw/Raw data-18938,18940,18939-Trial     2.xlsx
# CPU times: user 6h 6min 14s, sys: 30.3 s, total: 6h 6min 44s
# Wall time: 6h 7min 33s
